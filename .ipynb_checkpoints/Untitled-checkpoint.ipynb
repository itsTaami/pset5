# %%
import pandas as pd

df = pd.read_excel("unegui_car_listings_complete.xlsx")

df.head()
# Out:
#                                 Title  \
# 0              Infiniti QX, 2018/2018
# 1  Toyota Land Cruiser 300, 2023/2023
# 2          Toyota Prius 50, 2017/2025
# 3                BYD Бусад, 2024/2025
# 4              Toyota Axio, 2012/2021
#
#                                                 Link      Price  \
# 0  https://www.unegui.mn/adv/9344901_infiniti-qx-...   150 сая₮
# 1  https://www.unegui.mn/adv/9874937_toyota-land-...   320 сая₮
# 2  https://www.unegui.mn/adv/9812153_toyota-prius...  27.6 сая₮
# 3  https://www.unegui.mn/adv/9874898_byd-busad-20...    85 сая₮
# 4  https://www.unegui.mn/adv/9874865_toyota-axio-...  14.8 сая₮
#
#   Engine_Capacity Transmission Steering           Type       Color  \
# 0           2.7 л      Автомат      Зөв           Жийп         Хар
# 1           3.5 л      Автомат      Зөв           Жийп         Хар
# 2           1.8 л      Автомат    Буруу  Суудлын тэрэг      Цагаан
# 3           1.5 л      Автомат      Зөв  Суудлын тэрэг  Хар саарал
# ...

# %%
df = df.drop(columns=['Doors'])

# %%
df.head()
# Out:
#                                 Title  \
# 0              Infiniti QX, 2018/2018
# 1  Toyota Land Cruiser 300, 2023/2023
# 2          Toyota Prius 50, 2017/2025
# 3                BYD Бусад, 2024/2025
# 4              Toyota Axio, 2012/2021
#
#                                                 Link      Price  \
# 0  https://www.unegui.mn/adv/9344901_infiniti-qx-...   150 сая₮
# 1  https://www.unegui.mn/adv/9874937_toyota-land-...   320 сая₮
# 2  https://www.unegui.mn/adv/9812153_toyota-prius...  27.6 сая₮
# 3  https://www.unegui.mn/adv/9874898_byd-busad-20...    85 сая₮
# 4  https://www.unegui.mn/adv/9874865_toyota-axio-...  14.8 сая₮
#
#   Engine_Capacity Transmission Steering           Type       Color  \
# 0           2.7 л      Автомат      Зөв           Жийп         Хар
# 1           3.5 л      Автомат      Зөв           Жийп         Хар
# 2           1.8 л      Автомат    Буруу  Суудлын тэрэг      Цагаан
# 3           1.5 л      Автомат      Зөв  Суудлын тэрэг  Хар саарал
# ...

# %%
df.to_csv("updated_file.csv", index=False)
